# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix, accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
data=pd.read_csv('heart.csv')

# %% [markdown]
# Age & Heart Disease

# %%
# Cross validation
X=data[['age']]
y=data.target
lr=LogisticRegression(class_weight='balanced')
scores=cross_val_score(lr,X,y,cv=5)
# Plotting the scores
plt.plot(range(1, len(scores) + 1), scores, marker='o', linestyle='-', color='b')
plt.title('Cross-validation Scores per Fold')
plt.xlabel('Fold')
plt.ylabel('Score')
plt.ylim(0, 1)  # Assuming scores are between 0 and 1
plt.xticks(range(1, len(scores) + 1))  # To ensure the x-axis only shows fold numbers
plt.grid(True)
plt.show()
print("Cross-validation scores:", scores)
print("Mean score:", scores.mean())
# Out:
# Cross-validation scores: [0.64390244 0.69268293 0.66341463 0.6097561  0.60487805]
# Mean score: 0.6429268292682927

# %%
y_pred = lr.predict(X)
print(confusion_matrix(y, y_pred))
# Out:
# [[413  86]
#  [300 226]]

# %%
lr.fit(X,y)
new_X=np.array([[60]])
predictions = lr.predict(new_X)

# If you want the probabilities instead of the predicted classes:
probabilities = lr.predict_proba(new_X)

# Output the predictions
print("Predictions:", predictions)
print("Probabilities:", probabilities)
# Out:
# Predictions: [0]
# Probabilities: [[0.57221232 0.42778768]]
# c:\Users\WIN11\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# c:\Users\WIN11\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Sex & Heart Disease

# %%
# Cross validation
X=data.sex.values.reshape(-1, 1)
y=data.target
lr=LogisticRegression()
scores=cross_val_score(lr,X,y,cv=5)
# Plotting the scores
plt.plot(range(1, len(scores) + 1), scores, marker='o', linestyle='-', color='b')
plt.title('Cross-validation Scores per Fold')
plt.xlabel('Fold')
plt.ylabel('Score')
plt.ylim(0, 1)  # Assuming scores are between 0 and 1
plt.xticks(range(1, len(scores) + 1))  # To ensure the x-axis only shows fold numbers
plt.grid(True)
plt.show()
print("Cross-validation scores:", scores)
print("Mean score:", scores.mean())
# Out:
# Cross-validation scores: [0.59512195 0.64390244 0.63414634 0.64878049 0.59512195]
# Mean score: 0.6234146341463415

# %%
# Step 1: Train the model on the entire dataset
lr.fit(X, y)

# Step 2: Predicting on new data
# Assuming 'new_data' is a DataFrame or array with the same structure as 'data.sex'
new_X = np.array([[0], [1]])# new_data.sex.values.reshape(-1, 1)
predictions = lr.predict(new_X)

# If you want the probabilities instead of the predicted classes:
probabilities = lr.predict_proba(new_X)

# Output the predictions
print("Predictions:", predictions)
print("Probabilities:", probabilities)
# Out:
# Predictions: [1 0]
# Probabilities: [[0.27969761 0.72030239]
#  [0.57749005 0.42250995]]
